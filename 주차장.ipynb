# %%
import pandas as pd
data = pd.read_csv("C:/Users/dksxo/Downloads/전국주차장정보표준데이터.csv",encoding="cp949")
import folium

# %%
data_sub = data[['위도', '경도']]

# %%
data_sub=data_sub[data['소재지지번주소'].str.contains('경기도', na=False) |
          data['소재지도로명주소'].str.contains('경기도', na=False)]

# %%
data
# Out:
#             주차장관리번호        주차장명 주차장구분 주차장유형 소재지도로명주소              소재지지번주소  \
# 0      186-2-000015    신성동 제2공영    공영    노외      NaN  대전광역시 유성구 신성동 211-2
# 1      186-2-000016  덕명지구 공영(1)    공영    노외      NaN    대전광역시 유성구 덕명동 544
# 2      186-2-000017  덕명지구 공영(2)    공영    노외      NaN    대전광역시 유성구 구암동 657
# 3      186-2-000018  덕명지구 공영(3)    공영    노외      NaN    대전광역시 유성구 구암동 677
# 4      186-2-000019  덕명지구 공영(4)    공영    노외      NaN    대전광역시 유성구 덕명동 544
# ...             ...         ...   ...   ...      ...                  ...
# 14797  272-2-000002  충주천제2공영주차장    공영    노외      NaN      충청북도 충주시 성서동453
# 14798  272-2-000003     칠금공영주차장    공영    노외      NaN     충청북도 충주시 칠금동1017
# 14799  272-2-000004     금릉공영주차장    공영    노외      NaN      충청북도 충주시 금릉동730
# 14800  272-2-000005    연수1공영주차장    공영    노외      NaN    충청북도 충주시 연수동 1538
# 14801  272-2-000006    연수2공영주차장    공영    노외      NaN    충청북도 충주시 연수동 1466
#
#        주차구획수 급지구분 부제시행구분        운영요일  ...   월정기권요금         결제방법 특기사항  \
# ...

# %%
data_sub = data_sub.dropna()

# %%
data_sub
# Out:
#               위도          경도
# 252    37.901743  127.199671
# 472    37.446271  127.166525
# 512    37.432954  127.142117
# 513    37.436671  127.155099
# 514    37.435885  127.166118
# ...          ...         ...
# 14775  37.832252  127.150177
# 14776  37.827550  127.150689
# 14777  37.784755  127.226858
# 14778  37.847225  127.188890
# 14779  38.001781  127.243041
#
# [1934 rows x 2 columns]

# %%
base_latitude = data_sub['위도'].mean()
base_longitude = data_sub['경도'].mean()

# %%
map = folium.Map(location=[base_latitude, base_longitude],
                 zoom_start=10)

# %%
for n in data_sub.index:
    latitude = data['위도'][n]
    longitude = data['경도'][n]
    
    iframe = folium.IFrame('<b>' + data['주차장명'][n] + '</b><br><br>')
    popup = folium.Popup(iframe, min_width=300, max_width=300)
    folium.Marker(
        [latitude, longitude],
        popup = popup,
        tooltip = data['주차장명'][n]
    ).add_to(map)

# html로 저장
map.save('주차장.html')
